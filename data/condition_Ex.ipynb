# %%
import pandas as pd
df = pd.read_csv("청년정책목록_전처리완료_2025-06-09.csv")

# %%
from condition import *

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("API_KEY")

# %%
condition_df = create_condition_table(df,api_key )
# Out:
# 조건 추출 중:   0%|          | 0/327 [00:00<?, ?it/s]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   0%|          | 1/327 [00:11<1:00:49, 11.20s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   1%|          | 2/327 [00:21<59:17, 10.95s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   1%|          | 3/327 [00:27<46:58,  8.70s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   1%|          | 4/327 [00:32<37:27,  6.96s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   2%|▏         | 5/327 [00:36<31:49,  5.93s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# 조건 추출 중:   2%|▏         | 6/327 [00:38<24:27,  4.57s/it]
# [조건 추출 오류]: Expecting value: line 1 column 1 (char 0)
# ...

# %%
condition_df.to_csv("정책_조건테이블.csv", index=False, encoding='utf-8-sig')
