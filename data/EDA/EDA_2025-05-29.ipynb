# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
df = pd.read_excel("청년정책목록_전체_매핑완료.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3458 entries, 0 to 3457
# Data columns (total 60 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   정책번호         3458 non-null   object
#  1   기본계획차수       3458 non-null   int64
#  2   기본계획정책방향번호   3458 non-null   int64
#  3   기본계획중점과제번호   3458 non-null   int64
#  4   기본계획과제번호     3458 non-null   int64
#  5   제공기관그룹코드     3458 non-null   object
#  6   정책제공방법코드     623 non-null    object
#  7   정책승인상태코드     3458 non-null   object
#  8   정책명          3458 non-null   object
#  9   정책키워드명       956 non-null    object
#  10  정책설명내용       3458 non-null   object
#  11  정책대분류명       3421 non-null   object
#  12  정책중분류명       3421 non-null   object
#  13  정책지원내용       3458 non-null   object
#  14  주관기관코드       2464 non-null   object
#  15  주관기관코드명      3440 non-null   object
#  16  주관기관담당자명     766 non-null    object
#  17  운영기관코드       2089 non-null   object
#  18  운영기관코드명      2851 non-null   object
#  19  운영기관담당자명     491 non-null    object
#  20  지원규모제한여부     3458 non-null   object
#  21  신청기간구분코드     3458 non-null   object
#  22  사업기간구분코드     619 non-null    object
#  23  사업기간시작일자     757 non-null    object
#  24  사업기간종료일자     757 non-null    object
#  25  사업기간기타내용     1808 non-null   object
#  26  정책신청방법내용     2926 non-null   object
#  27  심사방법내용       2044 non-null   object
#  28  신청URL주소      1579 non-null   object
#  29  제출서류내용       2226 non-null   object
#  30  기타사항내용       2175 non-null   object
#  31  참고URL주소1     2557 non-null   object
#  32  참고URL주소2     536 non-null    object
#  33  지원규모수        1411 non-null   float64
#  34  지원도착순서여부     3458 non-null   object
#  35  지원대상최소연령     2453 non-null   float64
#  36  지원대상최대연령     2390 non-null   float64
#  37  지원대상연령제한여부   3458 non-null   object
#  38  결혼상태코드       638 non-null    object
#  39  소득조건구분코드     615 non-null    object
#  40  소득최소금액       580 non-null    float64
#  41  소득최대금액       580 non-null    float64
#  42  소득기타내용       97 non-null     object
#  43  추가신청자격조건내용   1964 non-null   object
#  44  참여제안대상내용     1887 non-null   object
#  45  조회수          3458 non-null   int64
#  46  등록자기관코드      3416 non-null   object
#  47  등록자기관코드명     3416 non-null   object
#  48  등록자상위기관코드    3416 non-null   object
#  49  등록자상위기관코드명   3413 non-null   object
#  50  등록자최상위기관코드   3416 non-null   object
#  51  등록자최상위기관코드명  3413 non-null   object
#  52  정책거주지역코드     3458 non-null   object
#  53  정책전공요건코드     3458 non-null   object
#  54  정책취업요건코드     3458 non-null   object
#  55  정책학력요건코드     3458 non-null   object
#  56  신청기간         2319 non-null   object
#  57  최초등록일시       3458 non-null   object
#  58  최종수정일시       3458 non-null   object
#  59  정책특화요건코드     3458 non-null   object
# dtypes: float64(5), int64(5), object(50)
# memory usage: 1.6+ MB

# %%
# '정책대분류명'이 '교육'이 들어간 데이터 필터링
education_df = df[df['정책대분류명'].str.contains('교육', na=False)]
print(f"전체 데이터 수: {len(df)}")
print(f"교육 관련 정책 수: {len(education_df)}")
print(f"교육 관련 정책 비율: {len(education_df)/len(df)*100:.2f}%")
# Out:
# 전체 데이터 수: 3458
# 교육 관련 정책 수: 546
# 교육 관련 정책 비율: 15.79%

# %%
# 교육 관련 정책 데이터 확인
education_df['정책대분류명'].head(10)
# Out:
# 0           교육
# 11          교육
# 12     일자리, 교육
# 36     일자리, 교육
# 58          교육
# 78          교육
# 99     일자리, 교육
# 111         교육
# 118         교육
# 119         교육
# Name: 정책대분류명, dtype: object

# %%
# 교육 관련 데이터의 '정책대분류명' 고유값 확인
print("교육 관련 정책대분류명:")
print(education_df['정책대분류명'].unique())
# Out:
# 교육 관련 정책대분류명:
# ['교육' '일자리, 교육' '일자리, 교육, 복지문화' '교육, 복지문화' '교육, 일자리' '교육, 참여권리'
#  '일자리, 교육, 참여권리' '교육, 주거' '복지문화, 교육' '일자리, 주거, 교육' '주거, 교육']

# %%
print(education_df.iloc[0])
# Out:
# 정책번호                                        20250521005400110863
# 기본계획차수                                                         1
# 기본계획정책방향번호                                                     3
# 기본계획중점과제번호                                                    10
# 기본계획과제번호                                                      23
# 제공기관그룹코드                                                    중앙부처
# 정책제공방법코드                                                      기타
# 정책승인상태코드                                                      승인
# 정책명                                                      주거안정장학금
# 정책키워드명                                                  보조금,교육지원
# 정책설명내용         원거리 대학 진학으로 인해 주거 관련 비용 부담이 큰 저소득 대학생을 대상으로 주거...
# 정책대분류명                                                        교육
# 정책중분류명                                                     교육비지원
# 정책지원내용         □ 지원금액: 월 최대 20만 원\n※ 단, 방학 중(7~8월, 1~2월)에는 지원...
# 주관기관코드                                                   1342000
# 주관기관코드명                                                      교육부
# 주관기관담당자명                                                     NaN
# 운영기관코드                                                   B552529
# 운영기관코드명                                                   한국장학재단
# 운영기관담당자명                                                     NaN
# 지원규모제한여부                                                       Y
# 신청기간구분코드                                                    특정기간
# 사업기간구분코드                                                      기타
# 사업기간시작일자
# 사업기간종료일자
# 사업기간기타내용                                                      연중
# 정책신청방법내용       □ 2학기 신청일정: 2025. 5. 23.(금) 9시 ~ 6. 23.(월) 18시...
# 심사방법내용         □ 선발결과 공개일: 10월 4 ~ 5주 예정\n- 선발결과 공개일은 재단 및 유관...
# 신청URL주소        https://www.kosaf.go.kr/ko/scholar.do?pg=schol...
# 제출서류내용         한국장학재단 홈페이지(https://www.kosaf.go.kr/ko/scholar...
# 기타사항내용                                                       NaN
# 참고URL주소1       https://www.kosaf.go.kr/ko/scholar.do?pg=schol...
# 참고URL주소2                                                     NaN
# 지원규모수                                                        0.0
# 지원도착순서여부                                                       N
# 지원대상최소연령                                                     0.0
# 지원대상최대연령                                                    39.0
# 지원대상연령제한여부                                                     N
# 결혼상태코드                                                        미혼
# 소득조건구분코드                                                      기타
# 소득최소금액                                                       0.0
# 소득최대금액                                                       0.0
# 소득기타내용                                          기초생활수급자 또는 차상위계층
# 추가신청자격조건내용     □ 학생 지원자격\n○ 대한민국 국적을 소지하고 재학 중인 대학생(대학원생 제외)\...
# 참여제안대상내용                                                     NaN
# 조회수                                                           42
# 등록자기관코드                                                  B551904
# 등록자기관코드명                                                 한국고용정보원
# 등록자상위기관코드                                                1492000
# 등록자상위기관코드명                                                 고용노동부
# 등록자최상위기관코드                                               1492000
# 등록자최상위기관코드명                                                고용노동부
# 정책거주지역코드                                                      전국
# 정책전공요건코드                                                    제한없음
# 정책취업요건코드                                                    제한없음
# 정책학력요건코드                                                   대학 재학
# 신청기간                                         20250523 ~ 20250623
# 최초등록일시                                       2025-05-21 15:36:19
# 최종수정일시                                       2025-05-21 17:13:42
# 정책특화요건코드                                                    제한없음
# Name: 0, dtype: object
