# %%
import pandas as pd

# CSV 파일 불러오기
df = pd.read_csv("청년정책_최종.csv")

# %%
job_df = df[df['정책대분류명'].str.contains('복지문화', na=False)].copy()

# %%
print(f"복지문화 관련 정책 수: {len(job_df)}")
# Out:
# 복지문화 관련 정책 수: 877

# %%
import pandas as pd
from collections import Counter
import re

# %%
top_10 = job_df.sort_values(by='조회수', ascending=False).head(10)

# %%
# 상위 10개 정책 출력
print("조회수 높은 복지문화 정책 10개:")
print(top_10[['정책명', '조회수']])
# Out:
# 조회수 높은 복지문화 정책 10개:
#                     정책명   조회수
# 331   2025년 전국민마음투자지원사업  3512
# 182            청년문화예술패스  2541
# 162            서울시 청년수당  1883
# 456   대학(원)생 생활안정지원금 지원  1459
# 541     청년층 정신건강 서비스 강화  1443
# 117         서울청년문화패스 지원   985
# 3302     [대전] 미래두배 청년통장   940
# 183            서울청년문화패스   921
# 21             청년내일저축계좌   875
# 116            청년예술청 운영   837
