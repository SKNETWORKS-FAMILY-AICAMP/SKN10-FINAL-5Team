# %%
import pandas as pd
df = pd.read_csv(r"C:\dev\SKN10-FINAL-5Team\LLM\eval_qa_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   평가지표     520 non-null    object
#  1   정책명      520 non-null    object
#  2   자연스러운질문  520 non-null    object
# dtypes: object(3)
# memory usage: 12.3+ KB

# %%
# 평가지표 개수 확인
print("평가지표 개수:", df['평가지표'].nunique())
print("\n평가지표 목록:")
print(df['평가지표'].unique())
# Out:
# 평가지표 개수: 6
#
# 평가지표 목록:
# ['정확성' '적합성' '검색' '유용성' '환각' '전환']

# %%
# 평가지표별 질문 개수 계산
metric_counts = df['평가지표'].value_counts()

# 결과 출력
print("평가지표별 질문 개수:")
print(metric_counts)

# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
metric_counts.plot(kind='bar')
plt.title('평가지표별 질문 개수')
plt.xlabel('평가지표')
plt.ylabel('질문 개수')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# 평가지표별 질문 개수:
# 평가지표
# 정확성    90
# 적합성    90
# 검색     90
# 유용성    90
# 환각     90
# 전환     70
# Name: count, dtype: int64
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_25912\1960291399.py:17: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_25912\1960291399.py:17: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_25912\1960291399.py:17: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_25912\1960291399.py:17: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
520/60
# Out:
# 8.666666666666666

# %%
# 정책별 질문 개수 계산
policy_counts = df['정책명'].value_counts()

# 결과 출력
print("정책별 질문 개수:")
print(policy_counts)
# 정책별 평균 질문 개수 계산
avg_questions_per_policy = len(df) / df['정책명'].nunique()
print(f"\n정책별 평균 질문 개수: {avg_questions_per_policy:.2f}")
# Out:
# 정책별 질문 개수:
# 정책명
# 청년전용 버팀목전세자금                        3
# 금연클리닉 운영                            3
# 청소년자립지원관                            3
# 청년 임차보증금 이자지원                       3
# 청년 면접정장 무료 대여 서비스 “면접 흥하시흥”(시흥시)    3
#                                    ..
# 결혼 비용 대출이자 지원사업                     2
# 청년정책위원회 및 청년참여단 운영                  2
# 울산 동구 청년문화예술 활성화 지원사업               2
# 강남 청년의 날 행사                         2
# 울산 동구 청년 문화강좌 개설 및 운영               2
# Name: count, Length: 180, dtype: int64
#
# 정책별 평균 질문 개수: 2.89

# %%
# 정책 개수 계산
total_policies = df['정책명'].nunique()
print(f"총 정책 개수: {total_policies}개")
# Out:
# 총 정책 개수: 180개
